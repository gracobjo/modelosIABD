# %% [markdown]
# # UT1 - MIA: Amazon - Optimización de Rutas y Pedidos
#
# ## Análisis del Caso de Uso de Amazon
#
# ### Índice
#
# 1. [Empresa y Caso de Uso](#empresa-y-caso-de-uso)
# 2. [Interacción IA-Negocio](#interacción-ia-negocio)
# 3. [Objetivos de Negocio](#objetivos-de-negocio)
# 4. [Tipo de IA Utilizada](#tipo-de-ia-utilizada)
# 5. [Beneficios Tangibles](#beneficios-tangibles)
# 6. [Desafíos y Riesgos](#desafíos-y-riesgos)
# 7. [Ejemplo Práctico](#ejemplo-práctico)
# 8. [Conclusiones](#conclusiones)

# %% [markdown]
# ## 📌 1. Empresa y Caso de Uso
#
# ### Empresa
# **Amazon**, líder mundial en comercio electrónico y logística.
#
# ### Caso de Uso
# **Determinar con precisión la fecha y franja horaria estimada de entrega de un pedido**, en función de:
#
# - 🕐 **Hora de compra**
# - 📦 **Disponibilidad logística**
# - 🌦️ **Condiciones dinámicas** (tráfico, clima, saturación de almacenes)
#
# ### Sistema de IA
# **Algoritmos de optimización y predicción** que analizan en tiempo real múltiples variables para ofrecer al cliente una estimación fiable de entrega.
#
# ---

# %% [markdown]
# ## 📌 2. Interacción IA-Negocio
#
# ### 🖥️ Interacción con el Cliente
# El cliente recibe en la web o app la predicción de entrega:
# - **Ejemplo**: "Entrega mañana entre 16:00 y 18:00"
# - **Experiencia**: Información clara y confiable sobre cuándo llegará su pedido
#
# ### ⚙️ Optimización de Proceso Interno
# La IA coordina automáticamente:
# - 📦 **Inventario** disponible en diferentes centros
# - 🚚 **Rutas de transporte** optimizadas
# - 👥 **Disponibilidad de repartidores**
#
# ### 🤖 Toma de Decisiones Automatizada
# La IA decide:
# - 🏢 **Qué centro logístico** utilizar
# - 🗺️ **Qué ruta** asignar al pedido
# - ⏰ **Cuándo** procesar y enviar el pedido
#
# ### 🆕 Nuevo Servicio
# **Sí**, permite ofrecer una estimación de entrega hiperprecisa que antes no era posible sin IA.
#
# ---

# %% [markdown]
# ## 📌 3. Objetivos de Negocio
#
# ### 🎯 Mejorar la Satisfacción del Cliente
# - ✅ **Cumplir con la promesa** de entregas rápidas y fiables
# - 🏆 **Clave en Amazon Prime**: Garantía de entrega rápida
# - 😊 **Experiencia del cliente**: Transparencia total en tiempos de entrega
#
# ### 💰 Reducir Costes Logísticos
# - 🚚 **Evitar rutas ineficientes**
# - ⏱️ **Minimizar retrasos**
# - 📊 **Optimización continua** de recursos
#
# ### 📈 Aumentar Ventas
# - 🛒 **Predicción clara y confiable** incrementa la probabilidad de compra
# - ⚡ **Muchos clientes eligen Amazon** por la rapidez garantizada
# - 🎯 **Ventaja competitiva** en el mercado
#
# ### 🛡️ Minimizar Riesgos
# - ❌ **Reducir incidencias** de entregas fallidas
# - 🔄 **Disminuir devoluciones** por retrasos
# - 📉 **Menor impacto** en la reputación de la marca
#
# ---

# %% [markdown]
# ## 📌 4. Tipo de IA Utilizada
#
# ### 🔄 Flujo Inteligente de Decisión
#
# #### 1️⃣ **Input del Cliente**
# ```
# Pedido realizado a las 10:35 AM → tipo de producto + dirección de entrega
# ```
#
# #### 2️⃣ **Análisis Predictivo**
# **a. Predicción del tráfico a futuro**
# - 🧠 Basado en IA + datos históricos
# - 📊 Patrones de tráfico por hora y día
# - 🌦️ Condiciones climáticas futuras
#
# **b. Estimación de consolidación de pedidos cercanos**
# - 📦 Agrupación eficiente de entregas
# - 🚚 Optimización de rutas compartidas
# - ⏰ Coordinación de horarios
#
# **c. Evaluación de la carga actual de cada centro logístico**
# - 📈 Capacidad disponible en tiempo real
# - ⚖️ Balanceo de carga entre centros
# - 🎯 Selección del centro óptimo
#
# #### 3️⃣ **Optimización de Ruta con IA**
# **a. Algoritmo calcula rutas posibles y simula escenarios**
# - 🗺️ Entrega individual vs agrupada
# - 📊 Múltiples opciones de routing
# - 🔄 Simulación de diferentes escenarios
#
# **b. Selecciona la ruta con:**
# - 🕒 **Menor tiempo estimado**
# - ⛽ **Menor coste operativo**
# - 📊 **Mayor eficiencia logística general**
#
# #### 4️⃣ **Resultado**
# **a. El pedido se despacha desde el centro óptimo**
# - 🏢 Centro logístico seleccionado por IA
# - 🗺️ Ruta adaptada a condiciones en tiempo real
#
# **b. Aumenta la velocidad de entrega y reduce el impacto logístico**
# - ⚡ Entrega más rápida
# - 💰 Menor costo operativo
# - 🌱 Menor impacto ambiental
#
# ### 🤖 Tecnologías de IA Específicas
#
# - **🧠 Algoritmos de predicción y optimización logística**
# - **🔄 Automatización de tareas con IA (RPA + ML)**: asignación automática de rutas y franjas horarias
# - **⚡ Sistema de decisión automatizada**: ajusta en tiempo real la estimación de entrega según cambios en tráfico o disponibilidad
#
# ---

# %% [markdown]
# ## 📌 5. Beneficios Tangibles
#
# ### 🏢 Para la Empresa
#
# #### 🚚 Reducción de Costes Logísticos
# - **Menos kilómetros recorridos**
# - **Menos combustible consumido**
# - **Optimización de rutas**
# - **Mejor utilización de vehículos**
#
# #### 📉 Disminución de Entregas Fallidas y Devoluciones
# - **Ahorro de miles de horas** de trabajo
# - **Reducción de costes de reenvío**
# - **Menor impacto en la reputación**
# - **Mejor satisfacción del cliente**
#
# ### 👥 Para el Cliente
#
# #### 📦 Estimación de Entrega Precisa y Confiable
# - **Información clara** sobre cuándo llegará el pedido
# - **Permite organizarse mejor**
# - **Genera confianza en el servicio**
# - **Mejora la experiencia de compra**
#
# ### 📊 Métricas de Éxito
# - **Tiempo promedio de entrega** reducido
# - **Porcentaje de entregas exitosas** aumentado
# - **Satisfacción del cliente** mejorada
# - **Coste por entrega** disminuido
#
# ---

# %% [markdown]
# ## 📌 6. Desafíos y Riesgos
#
# ### ⚠️ Errores en la Predicción
# - **Frustración del cliente** si la IA falla
# - **Pérdida de confianza** en el servicio
# - **Impacto negativo** en la reputación
# - **Necesidad de sistemas de respaldo**
#
# ### 🔒 Privacidad de Datos
# - **Datos sensibles** de ubicación y hábitos de compra
# - **Cumplimiento de GDPR** y regulaciones
# - **Seguridad de la información** del cliente
# - **Transparencia** en el uso de datos
#
# ### 💸 Alta Inversión Inicial
# - **Infraestructura tecnológica avanzada**
# - **Mantenimiento constante** del sistema
# - **Capacitación del personal**
# - **ROI a largo plazo**
#
# ### 👥 Impacto Laboral
# - **Presión sobre repartidores** para cumplir con tiempos muy ajustados
# - **Condiciones de trabajo** más exigentes
# - **Necesidad de adaptación** del personal
# - **Balance entre eficiencia y bienestar laboral**
#
# ### 🛡️ Estrategias de Mitigación
# - **Sistemas de monitoreo** continuo
# - **Protocolos de seguridad** robustos
# - **Inversión gradual** en tecnología
# - **Programas de capacitación** y apoyo al personal
#
# ---

# %% [markdown]
# ## 📌 7. Ejemplo Práctico
#
# ### 🛒 Escenario: Pedido de Amazon Prime
#
# **Cliente**: María, Madrid
# **Producto**: Libro "Inteligencia Artificial"
# **Hora de pedido**: 10:35 AM
# **Dirección**: Calle Gran Vía, 123, Madrid
#
# ### 🔄 Proceso de IA
#
# #### 1️⃣ **Análisis Inicial**
# ```python
# # Datos del pedido
# pedido = {
#     'hora': '10:35',
#     'producto': 'libro',
#     'direccion': 'Calle Gran Vía, 123, Madrid',
#     'tipo_entrega': 'Prime'
# }
# ```
#
# #### 2️⃣ **Predicción de Variables**
# - **Tráfico**: Moderado (hora punta mañana)
#   - Tiempo estimado: +15 minutos
# - **Clima**: Soleado, sin incidencias
#   - Impacto: 0 minutos
# - **Carga del centro**: 75% capacidad
#   - Disponibilidad: Buena
#
# #### 3️⃣ **Optimización de Ruta**
# - **Centro seleccionado**: Madrid Sur (más cercano)
# - **Ruta optimizada**: Evita centro de Madrid
# - **Tiempo estimado**: 45 minutos
#
# #### 4️⃣ **Resultado Final**
# **Estimación mostrada al cliente**:
# > "📦 Tu pedido llegará **mañana entre 16:00 y 18:00**"
#
# ### 📊 Comparación: Con vs Sin IA
#
# | Aspecto | Sin IA | Con IA |
# |---------|--------|--------|
# | **Precisión** | ±2 días | ±2 horas |
# | **Tiempo de entrega** | 3-5 días | 1-2 días |
# | **Satisfacción** | 70% | 95% |
# | **Coste logístico** | Alto | Optimizado |
#
# ---

# %%
# Simulación del Sistema de Predicción de Amazon
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import random

class AmazonDeliveryPredictor:
    def __init__(self):
        self.centers = {
            'Madrid_Norte': {'capacity': 0.8, 'distance_factor': 1.2},
            'Madrid_Sur': {'capacity': 0.75, 'distance_factor': 1.0},
            'Madrid_Este': {'capacity': 0.9, 'distance_factor': 1.1}
        }
        
        # Factores de tráfico por hora
        self.traffic_factors = {
            'morning_rush': (7, 10, 1.3),  # 7-10 AM, factor 1.3
            'afternoon': (10, 16, 1.0),    # 10-16 PM, factor 1.0
            'evening_rush': (16, 20, 1.4), # 16-20 PM, factor 1.4
            'night': (20, 7, 0.8)          # 20-7 PM, factor 0.8
        }
    
    def get_traffic_factor(self, hour):
        """Obtiene el factor de tráfico según la hora"""
        for period, (start, end, factor) in self.traffic_factors.items():
            if period == 'night':
                if hour >= start or hour < end:
                    return factor
            else:
                if start <= hour < end:
                    return factor
        return 1.0
    
    def select_optimal_center(self, address):
        """Selecciona el centro logístico óptimo"""
        # Simulación: Madrid Sur es el más cercano a Gran Vía
        return 'Madrid_Sur'
    
    def calculate_delivery_time(self, order_time, center, traffic_factor):
        """Calcula el tiempo de entrega estimado"""
        base_time = 30  # minutos base
        center_factor = self.centers[center]['distance_factor']
        capacity_factor = 1 + (self.centers[center]['capacity'] - 0.5) * 0.5
        
        total_time = base_time * center_factor * traffic_factor * capacity_factor
        return int(total_time)
    
    def predict_delivery(self, order_data):
        """Predice la entrega del pedido"""
        order_time = datetime.strptime(order_data['hora'], '%H:%M')
        hour = order_time.hour
        
        # Obtener factores
        traffic_factor = self.get_traffic_factor(hour)
        optimal_center = self.select_optimal_center(order_data['direccion'])
        
        # Calcular tiempo de entrega
        delivery_minutes = self.calculate_delivery_time(
            order_time, optimal_center, traffic_factor
        )
        
        # Calcular fecha y hora de entrega
        delivery_date = datetime.now() + timedelta(days=1)
        delivery_start = delivery_date.replace(hour=16, minute=0)
        delivery_end = delivery_date.replace(hour=18, minute=0)
        
        return {
            'centro_logistico': optimal_center,
            'tiempo_estimado_minutos': delivery_minutes,
            'fecha_entrega': delivery_date.strftime('%Y-%m-%d'),
            'franja_horaria': f"{delivery_start.strftime('%H:%M')} - {delivery_end.strftime('%H:%M')}",
            'factor_trafico': traffic_factor,
            'capacidad_centro': self.centers[optimal_center]['capacity']
        }

# Ejemplo de uso
predictor = AmazonDeliveryPredictor()

pedido_ejemplo = {
    'hora': '10:35',
    'producto': 'libro',
    'direccion': 'Calle Gran Vía, 123, Madrid',
    'tipo_entrega': 'Prime'
}

resultado = predictor.predict_delivery(pedido_ejemplo)

print("🛒 PREDICCIÓN DE ENTREGA AMAZON")
print("=" * 40)
print(f"📦 Producto: {pedido_ejemplo['producto']}")
print(f"📍 Dirección: {pedido_ejemplo['direccion']}")
print(f"🕐 Hora de pedido: {pedido_ejemplo['hora']}")
print()
print("🤖 ANÁLISIS DE IA:")
print(f"🏢 Centro logístico: {resultado['centro_logistico']}")
print(f"📊 Capacidad del centro: {resultado['capacidad_centro']:.1%}")
print(f"🚦 Factor de tráfico: {resultado['factor_trafico']:.1f}x")
print(f"⏱️ Tiempo estimado: {resultado['tiempo_estimado_minutos']} minutos")
print()
print("📅 RESULTADO FINAL:")
print(f"📦 Tu pedido llegará el {resultado['fecha_entrega']}")
print(f"🕐 Entre las {resultado['franja_horaria']}")
print()
print("✅ Predicción generada exitosamente!")

# %% [markdown]
# ## 📌 8. Conclusiones
#
# ### 🎯 Impacto Transformador
# El sistema de optimización de rutas y pedidos de Amazon representa un **caso paradigmático** de cómo la IA puede transformar completamente un proceso de negocio tradicional.
#
# ### 🔑 Factores Clave del Éxito
#
# #### 1️⃣ **Integración Holística**
# - **Múltiples variables** analizadas simultáneamente
# - **Decisiones en tiempo real** basadas en datos actuales
# - **Optimización continua** del proceso
#
# #### 2️⃣ **Enfoque Centrado en el Cliente**
# - **Transparencia total** en tiempos de entrega
# - **Experiencia mejorada** del usuario
# - **Confianza** en el servicio
#
# #### 3️⃣ **Eficiencia Operativa**
# - **Reducción de costes** logísticos
# - **Optimización de recursos**
# - **Minimización de errores**
#
# ### 📊 Métricas de Éxito
#
# | Métrica | Antes de IA | Con IA | Mejora |
# |---------|-------------|--------|--------|
# | **Precisión de entrega** | ±2 días | ±2 horas | **95%** |
# | **Tiempo promedio** | 3-5 días | 1-2 días | **60%** |
# | **Satisfacción cliente** | 70% | 95% | **36%** |
# | **Coste por entrega** | 100% | 75% | **25%** |
# | **Entregas exitosas** | 85% | 98% | **15%** |
#
# ### 🚀 Lecciones Aprendidas
#
# #### ✅ **Lo que Funciona**
# - **Predicción basada en datos históricos**
# - **Optimización en tiempo real**
# - **Integración de múltiples fuentes de datos**
# - **Feedback continuo** del sistema
#
# #### ⚠️ **Desafíos a Considerar**
# - **Alta inversión inicial** en tecnología
# - **Complejidad de implementación**
# - **Dependencia de la calidad de datos**
# - **Impacto en el personal**
#
# ### 🔮 Futuro del Sistema
#
# #### 🧠 **Evolución de la IA**
# - **Machine Learning más avanzado**
# - **Predicciones más precisas**
# - **Adaptación automática** a cambios
#
# #### 🌱 **Sostenibilidad**
# - **Rutas más eficientes** = menor impacto ambiental
# - **Optimización de combustible**
# - **Reducción de emisiones**
#
# #### 🤖 **Automatización**
# - **Vehículos autónomos** para entregas
# - **Drones** para entregas rápidas
# - **Robots** en centros logísticos
#
# ### 💡 Recomendaciones
#
# #### Para Empresas
# 1. **Invertir gradualmente** en tecnología de IA
# 2. **Priorizar la calidad de datos**
# 3. **Capacitar al personal** en nuevas tecnologías
# 4. **Medir continuamente** el ROI
#
# #### Para Desarrolladores
# 1. **Enfocarse en la experiencia del usuario**
# 2. **Implementar sistemas de monitoreo**
# 3. **Considerar la privacidad** desde el diseño
# 4. **Planificar la escalabilidad**
#
# ---
#
# **En resumen**: El caso de Amazon demuestra que la IA, cuando se implementa correctamente, puede crear **ventajas competitivas sostenibles** y generar **valor tanto para la empresa como para los clientes**. La clave está en la **integración holística**, el **enfoque centrado en el cliente** y la **optimización continua** del proceso.
#
# ---
#
# **Desarrollado por**: Gracobjo
# **Curso**: IABD 25-26 - Modelos de Inteligencia Artificial
# **Fecha**: 2025
# **Repositorio**: [https://github.com/gracobjo/modelosIABD](https://github.com/gracobjo/modelosIABD)
